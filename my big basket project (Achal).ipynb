# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.read_csv("C:/Users/kushal dixit/Downloads/BigBasket Products.csv")
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %%
df = pd.read_csv("C:/Users/kushal dixit/Downloads/BigBasket Products.csv")

df
# Out:
#        index                                            product  \
# 0          1             Garlic Oil - Vegetarian Capsule 500 mg
# 1          2                              Water Bottle - Orange
# 2          3                     Brass Angle Deep - Plain, No.2
# 3          4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4          5                 Creme Soft Soap - For Hands & Body
# ...      ...                                                ...
# 27550  27551         Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                           Rosemary
# 27552  27553                       Peri-Peri Sweet Potato Chips
# 27553  27554                          Green Tea - Pure Original
# 27554  27555                     United Dreams Go Far Deodorant
#
#                      category              sub_category  \
# 0            Beauty & Hygiene                 Hair Care
# 1      Kitchen, Garden & Pets     Storage & Accessories
# ...

# %% [markdown]
# # Data Exploration

# %%
df.head()
# Out:
#    index                                            product  \
# 0      1             Garlic Oil - Vegetarian Capsule 500 mg
# 1      2                              Water Bottle - Orange
# 2      3                     Brass Angle Deep - Plain, No.2
# 3      4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4      5                 Creme Soft Soap - For Hands & Body
#
#                  category           sub_category              brand  \
# 0        Beauty & Hygiene              Hair Care  Sri Sri Ayurveda
# 1  Kitchen, Garden & Pets  Storage & Accessories         Mastercook
# 2    Cleaning & Household            Pooja Needs                Trm
# 3    Cleaning & Household   Bins & Bathroom Ware             Nakoda
# 4        Beauty & Hygiene       Bath & Hand Wash              Nivea
#
#    sale_price  market_price                      type  rating  \
# 0       220.0         220.0          Hair Oil & Serum     4.1
# 1       180.0         180.0    Water & Fridge Bottles     2.3
# ...

# %%
df.head(12)
# Out:
#     index                                            product  \
# 0       1             Garlic Oil - Vegetarian Capsule 500 mg
# 1       2                              Water Bottle - Orange
# 2       3                     Brass Angle Deep - Plain, No.2
# 3       4  Cereal Flip Lid Container/Storage Jar - Assort...
# 4       5                 Creme Soft Soap - For Hands & Body
# 5       6                  Germ - Removal Multipurpose Wipes
# 6       7                                       Multani Mati
# 7       8                  Hand Sanitizer - 70% Alcohol Base
# 8       9  Biotin & Collagen Volumizing Hair Shampoo + Bi...
# 9      10               Scrub Pad - Anti- Bacterial, Regular
# 10     11                           Wheat Grass Powder - Raw
# 11     12                     Butter Cookies Gold Collection
#
#                   category            sub_category              brand  \
# 0         Beauty & Hygiene               Hair Care  Sri Sri Ayurveda
# ...

# %%
df.tail(12)
# Out:
#        index                                          product  \
# 27543  27544              Popcorn - French Butter & Pink Salt
# 27544  27545        Brass Dhoop Aarti With Wooden Handle,No.3
# 27545  27546  Toilet Cleaning Brush - Round With Holder (Big)
# 27546  27547                    Organic Powder - Garam Masala
# 27547  27548                                  Powder - Baking
# 27548  27549                      Apple Cider Vinegar Shampoo
# 27549  27550                             Papad - Garlic Disco
# 27550  27551       Wottagirl! Perfume Spray - Heaven, Classic
# 27551  27552                                         Rosemary
# 27552  27553                     Peri-Peri Sweet Potato Chips
# 27553  27554                        Green Tea - Pure Original
# 27554  27555                   United Dreams Go Far Deodorant
#
#                        category              sub_category  \
# 27543      Gourmet & World Food  Snacks, Dry Fruits, Nuts
# ...

# %%
# #statistical description of numerical data
df.describe()
# Out:
#              index     sale_price  market_price        rating
# count  27555.00000   27549.000000  27555.000000  18919.000000
# mean   13778.00000     334.648391    382.056664      3.943295
# std     7954.58767    1202.102113    581.730717      0.739217
# min        1.00000       2.450000      3.000000      1.000000
# 25%     6889.50000      95.000000    100.000000      3.700000
# 50%    13778.00000     190.320000    220.000000      4.100000
# 75%    20666.50000     359.000000    425.000000      4.300000
# max    27555.00000  112475.000000  12500.000000      5.000000

# %%
# information about the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27555 entries, 0 to 27554
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   index         27555 non-null  int64
#  1   product       27554 non-null  object
#  2   category      27555 non-null  object
#  3   sub_category  27555 non-null  object
#  4   brand         27554 non-null  object
#  5   sale_price    27549 non-null  float64
#  6   market_price  27555 non-null  float64
#  7   type          27555 non-null  object
#  8   rating        18919 non-null  float64
#  9   description   27440 non-null  object
# dtypes: float64(3), int64(1), object(6)
# memory usage: 2.1+ MB

# %%
# check the null or empty value
df.isnull().sum()
# Out:
# index           0
# product         1
# category        0
# sub_category    0
# brand           1
# sale_price      6
# market_price    0
# type            0
# rating          0
# description     0
# discount        6
# dtype: int64

# %%
# check the duplicates
df.duplicated().sum()
# Out:
# 0

# %%
# check the shape of the dataset , it check how many rows and column are there
num_rows = df.shape[0]
num_columns=df.shape[1]
print(f" total number of rows in the dataset :{num_rows}")
print(f" total number of columns in the dataset:{num_columns}")
# Out:
#  total number of rows in the dataset :27555
#  total number of columns in the dataset:11

# %%
for col in df.columns:
    print(f"Unique values in '{col}':", df[col].nunique())
# Out:
# Unique values in 'index': 27555
# Unique values in 'product': 23540
# Unique values in 'category': 11
# Unique values in 'sub_category': 90
# Unique values in 'brand': 2313
# Unique values in 'sale_price': 3261
# Unique values in 'market_price': 1348
# Unique values in 'type': 426
# Unique values in 'rating': 40
# Unique values in 'description': 21944

# %%
# Fill missing values in 'rating' column with the average rating
# Replace missing values in 'description' column with an empty string

mean_rating = df['rating'].mean()
df['rating'] = df['rating'].fillna(mean_rating)
df['description'] = df['description'].fillna('')

# %%
df.shape
# Out:
# (27555, 10)

# %%
df.isnull().sum()
# Out:
# index           0
# product         1
# category        0
# sub_category    0
# brand           1
# sale_price      6
# market_price    0
# type            0
# rating          0
# description     0
# dtype: int64

# %%
# we have sort the table how much raing of the product those have best rating they should bemost selling products

# Top 5 best selling products
top_sold = df.sort_values(by='rating', ascending=False).head(5)
print("Top 5 Sold Products:")
print(top_sold[['product', 'rating']])

# Least 5 sold products
least_sold = df.sort_values(by='rating', ascending=True).head(5)
print("\nLeast 5 Sold Products:")
print(least_sold[['product', 'rating']])
# Out:
# Top 5 Sold Products:
#                                                 product  rating
# 12386  Gel Toothpaste For Kids - Raspberry Flavor, Dora     5.0
# 7363       Energizing Luxury Shower Gel - Spearmint Oil     5.0
# 20882            Dishwash Liquid - Sweet Orange & Lemon     5.0
# 15378                   Hand Made Organic Charcoal Soap     5.0
# 20888                                    Dairy Whitener     5.0
#
# Least 5 Sold Products:
#                                                 product  rating
# 8143                        Fission Body Mist - For Man     1.0
# 7728                   Future Juice/water Glass Tumbler     1.0
# 760                               Aloe 90% Soothing Gel     1.0
# 8258                           Body Moisturising Lotion     1.0
# 4011  Insulated Stainless Steel Easy Sip Bottle - Wa...     1.0

# %%
# Replace missing values in 'rating' with the column's mean value to avoid gaps
# Replace missing values in 'description' with an empty string to handle missing text

print(df[['product', 'market_price', 'sale_price', 'discount']].head())
df['discount'] = df['market_price'] - df['sale_price']
# Out:
#                                              product  market_price  \
# 0             Garlic Oil - Vegetarian Capsule 500 mg         220.0
# 1                              Water Bottle - Orange         180.0
# 2                     Brass Angle Deep - Plain, No.2         250.0
# 3  Cereal Flip Lid Container/Storage Jar - Assort...         176.0
# 4                 Creme Soft Soap - For Hands & Body         162.0
#
#    sale_price  discount
# 0       220.0       0.0
# 1       180.0       0.0
# 2       119.0     131.0
# 3       149.0      27.0
# 4       162.0       0.0

# %%
# check the outliers anf if there then convert with mean

numeric_cols = ['sale_price', 'market_price', 'rating']

for col in numeric_cols:
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]
    print(f"Outliers in '{col}':", len(outliers))

    mean_val = df[col].mean()
    df.loc[(df[col] < lower_bound) | (df[col] > upper_bound), col] = mean_val
# Out:
# Outliers in 'sale_price': 365
# Outliers in 'market_price': 374
# Outliers in 'rating': 2953

# %%
# Plot Histogram (Distribution of a Numeric Column)
plt.figure(figsize=(8,5))
sns.histplot(df['rating'], bins=30, kde=True)
plt.title('Distribution of Ratings')
plt.xlabel('Rating')
plt.ylabel('Count')
plt.show()

# %%
# Boxplot to visualize the spread of 'sale_price' and identify outliers in the data.

plt.figure(figsize=(8,5))
sns.boxplot(x=df['sale_price'])
plt.title('Boxplot of Sale Price')
plt.show()

# %%
#  Countplot to show the frequency of products in each 'category'.  
# Rotating x-axis labels to make category names readable.

plt.figure(figsize=(10,6))
sns.countplot(x='category', data=df)
plt.title('Count of Products by Category')
plt.xticks(rotation=45)
plt.show()

# %%
#  Scatter plot to observe the relationship between 'market_price' and 'sale_price'.

plt.figure(figsize=(8,6))
sns.scatterplot(x='market_price', y='sale_price', data=df)
plt.title('Market Price vs Sale Price')
plt.show()

# %%
# Heatmap to display correlation coefficients between numeric columns, helping identify which variables are strongly related.

plt.figure(figsize=(8,6))
sns.heatmap(df.select_dtypes(include=['float64', 'int64']).corr(), annot=True, cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %%
# Bar plot to show average 'sale_price' for each product 'category'.  
# X-axis labels are rotated for better readability.

plt.figure(figsize=(10,6))
sns.barplot(x='category', y='sale_price', data=df)
plt.title('Average Sale Price by Category')
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df[['sale_price', 'market_price', 'rating']])
plt.show()

# %% [markdown]
# # final insights
# # In this project, we analyzed a real-world product sales dataset to extract meaningful business insights. By cleaning the data, such as handling missing values and replacing outliers with mean values, we ensured the accuracy and reliability of our analysis. Through exploration and visualization, we identified which products sold the most and which received higher discounts, providing a clearer picture of sales performance and promotional strategies. The correlation analysis between price, rating, and other variables revealed important relationships that can influence customer behavior. Overall, these insights support better decision-making in pricing, inventory management, and marketing, demonstrating how data-driven approaches can improve business outcomes.

# %% [markdown]
# # Conclusion
# # We analyzed a real product sales dataset by loading and understanding the data. Missing values in the rating column were filled, and outliers in numeric columns were replaced with mean values to improve data quality. Data types were also checked and corrected.
#
# # We explored the data by identifying top and least selling products, calculating discounts, and analyzing key statistics. Visualization helped reveal patterns in ratings, prices, and discounts, while a correlation heatmap showed relationships between numeric features.
